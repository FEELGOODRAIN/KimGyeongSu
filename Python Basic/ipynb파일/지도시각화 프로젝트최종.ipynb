# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
import json
import pandas as pd
from folium import plugins
from IPython.display import display

# %%
from geopy.geocoders import Nominatim
geo_local = Nominatim(user_agent='South Korea')

# %%
#한글패치
import platform
from matplotlib import font_manager , rc

if platform.system() == 'Darwin':
  rc('font' , family = 'AppleGothic')
elif platform.system() == 'Windows':
  path = 'C:/Windows/Fonts/malgun.ttf'
  font_name = font_manager.FontProperties(fname = path).get_name()
  rc('font' , family = font_name)
else:
  print('모름')

# %%
from geopy.geocoders import Nominatim
geo_local = Nominatim(user_agent='South Korea')
# 위도, 경도 반환하는 함수
def geocoding(address):
    try:
        geo = geo_local.geocode(address)
        x_y = [geo.latitude, geo.longitude]
        return x_y

    except:
        return [0,0]

# %%
#필요한 파일 로드
seoul_gdf = gpd.read_file('C:/k_digital/Pythonbasic/LARD_ADM_SECT_SGG_서울/LARD_ADM_SECT_SGG_11.shp', crs='EPSG:4326')
seoul_gdf1 = gpd.read_file('C:/Users/NT551_11TH/Desktop/4652_조민우_반출데이터_20231011/B402. 서울시 장애인시설 공간데이터/B402. 서울시 장애인시설 공간데이터/2. 파일데이터/2019/TL_DSPSN_FCLTY_ST_2019.shp', crs='EPSG:4326')
geo_path = '02. skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path , encoding = 'UTF-8'))
total = pd.read_csv('장애인 비율 통계.csv' , encoding = 'euc-kr')
aa = pd.read_excel('위도경도.xlsx')

jang_bokji = pd.read_csv('복지관.csv' , encoding = 'euc-kr')
jang_jae = pd.read_csv('직업재활시설.csv' , encoding = 'euc-kr')
jang_ji = pd.read_csv('지역사회재활시설.csv' , encoding = 'euc-kr')
jang_gu = pd.read_csv('장애인거주시설.csv' , encoding = 'euc-kr')

# %%
jang_bokji = jang_bokji[['시설명','시설주소']]
jang_bokji.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시설명     26 non-null     object
#  1   시설주소    26 non-null     object
# dtypes: object(2)
# memory usage: 544.0+ bytes

# %%
jang_bokji['시설주소']
# Out:
# 0                              서울특별시 영등포구 신길로 55
# 1                           서울특별시 마포구 망원2동 451-1
# 2        서울특별시 금천구 독산로 70C동 603호(현대지식산업센터) (시흥동)
# 3      서울특별시 영등포구 국회대로62길 14한국스카우트연맹 302호 (여의도동)
# 4                서울특별시 영등포구 선유로 1461213호 (양평동3가)
# 5     서울특별시 강동구 올림픽로98가길 6-14101호 (암사동, 세종그랑빌3차)
# 6               서울특별시 강동구 상암로81길 10-1 (상일동, 태건빌)
# 7                   서울특별시 강동구 천중로9길 40101호 (천호동)
# 8            서울특별시 성동구 성수이로 1445층 (성수동2가)(성수동2가)
# 9               서울특별시 동작구 사당로 253-31층 (사당동)(사당동)
# 10                   서울특별시 관악구 신림로 1584~5층 (신림동)
# 11        서울특별시 강남구 도곡로 416-0서울특별시립장애인행복플러스센터 2층
# 12             서울특별시 영등포구 영등포로64길 15울림동 1층 (신길동)
# 13                    서울특별시 은평구 통일로934 (불광동, 1층)
# 14      서울특별시 강남구 밤고개로1길 10, 826호 (수서동, 수서현대벤처빌)
# 15                     서울특별시 강남구 테헤란로8길 36 (역삼동)
# 16     서울특별시 양천구 중앙로 181, 지하층101호 (신정동, 복합메디컬타운)
# 17                   서울특별시 서대문구 증가로4길63-17 (홍은동)
# 18                  서울특별시 강남구 광평로60길22, 4층 (수서동)
# 19                 서울특별시 노원구 동일로250길 44-47 (상계동)
# 20               서울특별시 서대문구 세검정로 78-19, 1층 (홍제동)
# 21            서울특별시 용산구 백범로 329용산보건분소 4층 (원효로1가)
# 22                      서울특별시 종로구 종로17길 8 (종로2가)
# 23        서울특별시 영등포구 문래북로 1055~7층, 어울림센터 (당산동1가)
# 24                 서울특별시 강남구 논현로86길 21, 2층 (역삼동)
# 25                 서울특별시 도봉구 마들로 703, 4~6층 (도봉동)
# Name: 시설주소, dtype: object

# %%
for i in range(len(jang_bokji)):
    a = jang_bokji['시설주소'][i].split(' ')
    jang_bokji['시설주소'][i] = " ".join(a[0:4])
jang_bokji['시설주소']
# Out:
# 0                       서울특별시 영등포구 신길로 55
# 1                    서울특별시 마포구 망원2동 451-1
# 2                      서울특별시 금천구 독산로 70C동
# 3           서울특별시 영등포구 국회대로62길 14한국스카우트연맹
# 4                 서울특별시 영등포구 선유로 1461213호
# 5             서울특별시 강동구 올림픽로98가길 6-14101호
# 6                   서울특별시 강동구 상암로81길 10-1
# 7                  서울특별시 강동구 천중로9길 40101호
# 8                    서울특별시 성동구 성수이로 1445층
# 9                   서울특별시 동작구 사당로 253-31층
# 10                  서울특별시 관악구 신림로 1584~5층
# 11    서울특별시 강남구 도곡로 416-0서울특별시립장애인행복플러스센터
# 12               서울특별시 영등포구 영등포로64길 15울림동
# 13                 서울특별시 은평구 통일로934 (불광동,
# 14                   서울특별시 강남구 밤고개로1길 10,
# 15                    서울특별시 강남구 테헤란로8길 36
# 16                     서울특별시 양천구 중앙로 181,
# 17            서울특별시 서대문구 증가로4길63-17 (홍은동)
# 18                 서울특별시 강남구 광평로60길22, 4층
# 19                서울특별시 노원구 동일로250길 44-47
# 20                 서울특별시 서대문구 세검정로 78-19,
# 21                서울특별시 용산구 백범로 329용산보건분소
# 22                      서울특별시 종로구 종로17길 8
# 23               서울특별시 영등포구 문래북로 1055~7층,
# 24                   서울특별시 강남구 논현로86길 21,
# 25                     서울특별시 도봉구 마들로 703,
# Name: 시설주소, dtype: object

# %%
address = pd.read_csv('total1.csv' , encoding = 'euc-kr')
address.drop('Unnamed: 0' , axis = 1 , inplace = True)
address
# Out:
#                          시설이름                      상세주소         위도          경도
# 0             영등포구 장애인사랑나눔의 집         서울특별시 영등포구 신길로 55  37.510761  126.910306
# 1                     마포점자도서실      서울특별시 마포구 망원2동 451-1  37.559119  126.900558
# 2            사람희망 금천장애인자립생활센터   서울특별시 금천구 독산로 70C동 603호   0.000000    0.000000
# 3                해오름장애인자립생활센터     서울특별시 영등포구 국회대로62길 14   0.000000    0.000000
# 4                 이음장애인자립생활센터        서울특별시 영등포구 선유로 146   0.000000    0.000000
# 5   장애인자립생활주택(가형)-강동장애인자립생활센터   서울특별시 강동구 올림픽로98가길 6-14   0.000000    0.000000
# 6         장애인자립생활주택(다형) 해뜨는양지     서울특별시 강동구 상암로81길 10-1  37.546175  127.167803
# 7         장애인자립생활주택(가형)-해뜨는양지        서울특별시 강동구 천중로9길 40   0.000000    0.000000
# 8               성동발달장애인평생교육센터        서울특별시 성동구 성수이로 144   0.000000    0.000000
# 9               동작발달장애인평생교육센터       서울특별시 동작구 사당로 253-3   0.000000    0.000000
# 10             관악구발달장애인평생교육센터     서울특별시 관악구 신림로 1584~5층  37.485812  126.929116
# 11                 서울시그룹홈지원센터       서울특별시 강남구 도곡로 416-0   0.000000    0.000000
# 12                   꿈더하기지원센터     서울특별시 영등포구 영등포로64길 15   0.000000    0.000000
# 13              은평발달장애인평생교육센터          서울특별시 은평구 통일로934   0.000000    0.000000
# 14                강남장애인가족지원센터      서울특별시 강남구 밤고개로1길 10,  37.488013  127.101831
# 15            Good Job 자립생활센터       서울특별시 강남구 테헤란로8길 36  37.497355  127.031857
# 16             양천구발달장애인평생교육센터        서울특별시 양천구 중앙로 181,  37.519712  126.853125
# 17            서대문 발달장애인평생교육센터     서울특별시 서대문구 증가로4길63-17   0.000000    0.000000
# 18          강남세움 발달장애인 평생교육센터        서울특별시 강남구 광평로60길22   0.000000    0.000000
# 19              노원발달장애인평생교육센터      서울특별시 노원구 동일로250길 44   0.000000    0.000000
# 20               서대문장애인가족지원센터    서울특별시 서대문구 세검정로 78-19,  37.591880  126.944706
# 21               용산구장애인가족지원센터         서울특별시 용산구 백범로 329   0.000000    0.000000
# 22              종로발달장애인평생교육센터         서울특별시 종로구 종로17길 8  37.570728  126.988912
# 23           영등포구 발달장애인평생교육센터  서울특별시 영등포구 문래북로 1055~7층,  37.521580  126.886362
# 24              강남발달장애인평생교육센터      서울특별시 강남구 논현로86길 21,  37.500327  127.039202
# 25             도봉발달장애인 평생교육센터        서울특별시 도봉구 마들로 703,  37.662329  127.045879

# %%
latitudee = []
longitudee =[]

for i in address['상세주소']:
    latitudee.append(geocoding(i)[0])
    longitudee.append(geocoding(i)[1])

# %%
address_df = pd.DataFrame({'시설이름': address['시설이름'],'상세주소':address['상세주소'],'위도':latitudee,'경도':longitudee})
result = address_df[address_df['위도'] != 0]
result
# Out:
#                          시설이름                      상세주소         위도          경도
# 0             영등포구 장애인사랑나눔의 집         서울특별시 영등포구 신길로 55  37.510761  126.910306
# 1                     마포점자도서실      서울특별시 마포구 망원2동 451-1  37.559119  126.900558
# 3                해오름장애인자립생활센터     서울특별시 영등포구 국회대로62길 14  37.525889  126.917706
# 4                 이음장애인자립생활센터        서울특별시 영등포구 선유로 146  37.529655  126.892871
# 5   장애인자립생활주택(가형)-강동장애인자립생활센터   서울특별시 강동구 올림픽로98가길 6-14  37.550795  127.131682
# 6         장애인자립생활주택(다형) 해뜨는양지     서울특별시 강동구 상암로81길 10-1  37.546175  127.167803
# 7         장애인자립생활주택(가형)-해뜨는양지        서울특별시 강동구 천중로9길 40  37.546557  127.126925
# 8               성동발달장애인평생교육센터        서울특별시 성동구 성수이로 144  37.542162  127.056249
# 9               동작발달장애인평생교육센터       서울특별시 동작구 사당로 253-3  37.484482  126.979546
# 10             관악구발달장애인평생교육센터     서울특별시 관악구 신림로 1584~5층  37.485812  126.929116
# 11                 서울시그룹홈지원센터       서울특별시 강남구 도곡로 416-0  37.491146  127.036809
# 12                   꿈더하기지원센터     서울특별시 영등포구 영등포로64길 15  37.513058  126.915977
# 14                강남장애인가족지원센터      서울특별시 강남구 밤고개로1길 10,  37.488013  127.101831
# 15            Good Job 자립생활센터       서울특별시 강남구 테헤란로8길 36  37.497355  127.031857
# 16             양천구발달장애인평생교육센터        서울특별시 양천구 중앙로 181,  37.519712  126.853125
# 20               서대문장애인가족지원센터    서울특별시 서대문구 세검정로 78-19,  37.591880  126.944706
# 21               용산구장애인가족지원센터         서울특별시 용산구 백범로 329  37.540802  126.957565
# 22              종로발달장애인평생교육센터         서울특별시 종로구 종로17길 8  37.570728  126.988912
# 23           영등포구 발달장애인평생교육센터  서울특별시 영등포구 문래북로 1055~7층,  37.521580  126.886362
# 24              강남발달장애인평생교육센터      서울특별시 강남구 논현로86길 21,  37.500327  127.039202
# 25             도봉발달장애인 평생교육센터        서울특별시 도봉구 마들로 703,  37.662329  127.045879

# %%
#a 테이블에서 위도와 경도 , 그리고 구 이름만 가져오기
aa = aa.iloc[:,[2,3,4]]

#total과 테이블을 합치기 위해 기준이 되는 열 이름을 통일
aa.rename(columns = {'city' : 'GU_NAM'} , inplace = True)

# %%
#GU_NAM이라는 열 이름을 기준으로 total과 a를 통합.
total = pd.merge(total , aa , on = 'GU_NAM')

# %%
#지도를 그려본 결과 , 글씨가 많이 벗어나 있는 것들이 많았음. 세부적인 조정
total.loc[total['GU_NAM']=='양천구' , 'latitude'] = 37.52
total.loc[total['GU_NAM']=='서초구' , 'longitude'] = 127.00
total.loc[total['GU_NAM']=='동대문구' , 'latitude'] = 37.58
total.loc[total['GU_NAM']=='동대문구' , 'longitude'] = 127.07
total.loc[total['GU_NAM']=='노원구' , 'longitude'] = 127.07
total.loc[total['GU_NAM']=='은평구' , 'latitude'] = 37.61
total.loc[total['GU_NAM']=='종로구' , 'latitude'] = 37.60
total.loc[total['GU_NAM']=='성북구' , 'latitude'] = 37.60

# %%
#지도 그리기
seoul_map = folium.Map(location=[37.5665, 126.9780], zoom_start=10)
folium.Choropleth(
    geo_data=geo_str,
    data=total,
    columns=['GU_NAM', '장애인인구'],
    fill_color='GnBu',
    key_on='feature.properties.name', # json 파일과 total의 GU_NAM과 일치시킬 key값 찾기.
).add_to(seoul_map)

#지도의 구역마다 그 곳에 해당하는 구 이름을 text로 삽입.
for idx, row in total.iterrows():
    text = row['GU_NAM']
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        icon=folium.DivIcon(html=f'<div>{text}</div>') # 임의의 text값을 넣기 위해 html 형식으로 삽입.
    ).add_to(seoul_map)

folium.TileLayer('cartodbdark_matter').add_to(seoul_map)
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d8dfb745c8efa6344df00123a9f781c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d8dfb745c8efa6344df00123a9f781c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d8dfb745c8efa6344df00123a9f781c4 = L.map(
#                 &quot;map_d8dfb745c8efa6344df00123a9f781c4&quot;,
#                 {
#                     center: [37.5665, 126.978],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c18550b485cdaa7ab91c735d5625631 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d8dfb745c8efa6344df00123a9f781c4);
#
#
#             var choropleth_f415d47214c7ca374ea6d44ffab49eb7 = L.featureGroup(
#                 {}
#             ).addTo(map_d8dfb745c8efa6344df00123a9f781c4);
#
#
#         function geo_json_a1c966d1851119f36995f6a745a68b1f_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub0a8\uad6c&quot;: case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#a8ddb5&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ccebc5&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#0868ac&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc740\ud3c9\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#43a2ca&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc6a9\uc0b0\uad6c&quot;: case &quot;\uc911\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f0f9e8&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7bccc4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_a1c966d1851119f36995f6a745a68b1f_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_a1c966d1851119f36995f6a745a68b1f = L.geoJson(null, {
#                 onEachFeature: geo_json_a1c966d1851119f36995f6a745a68b1f_onEachFeature,
#
#                 style: geo_json_a1c966d1851119f36995f6a745a68b1f_styler,
#         });
#
#         function geo_json_a1c966d1851119f36995f6a745a68b1f_add (data) {
#             geo_json_a1c966d1851119f36995f6a745a68b1f
#                 .addData(data)
#                 .addTo(choropleth_f415d47214c7ca374ea6d44ffab49eb7);
#         }
#             geo_json_a1c966d1851119f36995f6a745a68b1f_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080893, 37.4624044

# %%
seoul_map = folium.Map(location=[37.5665, 126.9780], zoom_start=10)
folium.Choropleth(
    geo_data=geo_str,
    data=total,
    columns=['GU_NAM', '장애인비율'],
    fill_color='BuGn',
    key_on='feature.properties.name',
).add_to(seoul_map)

for idx, row in total.iterrows():
    text = row['GU_NAM']
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        icon=folium.DivIcon(html=f'<div>{text}</div>') 
    ).add_to(seoul_map)

folium.TileLayer('stamenwatercolor').add_to(seoul_map)
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec8f877b3e92e43dd9233f8fbcf78f43 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec8f877b3e92e43dd9233f8fbcf78f43&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ec8f877b3e92e43dd9233f8fbcf78f43 = L.map(
#                 &quot;map_ec8f877b3e92e43dd9233f8fbcf78f43&quot;,
#                 {
#                     center: [37.5665, 126.978],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d7deaf5578d2ad38a644f0ee83cdefe6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ec8f877b3e92e43dd9233f8fbcf78f43);
#
#
#             var choropleth_ce75a015f50af7c3df012701d0df44a0 = L.featureGroup(
#                 {}
#             ).addTo(map_ec8f877b3e92e43dd9233f8fbcf78f43);
#
#
#         function geo_json_d4f61139e64255f6269882e9735f2c4a_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;: case &quot;\uc911\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#66c2a4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ccece6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;: case &quot;\uc11c\ucd08\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#edf8fb&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2ca25f&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006d2c&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#99d8c9&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_d4f61139e64255f6269882e9735f2c4a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d4f61139e64255f6269882e9735f2c4a = L.geoJson(null, {
#                 onEachFeature: geo_json_d4f61139e64255f6269882e9735f2c4a_onEachFeature,
#
#                 style: geo_json_d4f61139e64255f6269882e9735f2c4a_styler,
#         });
#
#         function geo_json_d4f61139e64255f6269882e9735f2c4a_add (data) {
#             geo_json_d4f61139e64255f6269882e9735f2c4a
#                 .addData(data)
#                 .addTo(choropleth_ce75a015f50af7c3df012701d0df44a0);
#         }
#             geo_json_d4f61139e64255f6269882e9735f2c4a_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080893, 37.46240445587048], [1

# %%
import folium
from folium import plugins
from IPython.display import display

# %%
#불러온 파일에서 필요한 부분만 추출
jang_jae = jang_jae[['시설명','시설주소']]
jang_jae.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시설명     144 non-null    object
#  1   시설주소    142 non-null    object
# dtypes: object(2)
# memory usage: 2.4+ KB

# %%
#주소가 NA 처리되어 있으므로, NA값을 공백으로 채우기
jang_jae.fillna(' ' , inplace = True)
jang_jae
# Out:
#               시설명                               시설주소
# 0      임마누엘보호작업시설                서울특별시 송파구 양산로10길 26
# 1            아름다운  서울특별시 중랑구 망우로55길 32한국프라우드아파트 103호
# 2       마리스타보호작업장                   충청북도 충주시 지속골길 71
# 3    강북구립장애인보호작업장           서울특별시 강북구 오현로 199-9 (번동)
# 4    용산구립장애인보호작업장             서울특별시 용산구 한강대로 3311~2층
# ..            ...                                ...
# 139      금강직업재활시설
# 140            소담           서울특별시 중랑구 상봉로 695층 (면목동)
# 141         스프링샤인          서울특별시 은평구 갈현로11길 30 (구산동)
# 142           다가옴        서울특별시 강동구 고덕로 106201호 (암사동)
# 143         누야하우스           서울특별시 은평구 갈현로11길 30(구산동)
#
# [144 rows x 2 columns]

# %%
#주소값들을 'n층'과 같이 꼬리에 붙어있는 것들을 제거하고 순수 주소값으로 추출
for i in range(len(jang_jae)):
    a = jang_jae['시설주소'][i].split(' ')
    jang_jae['시설주소'][i] = " ".join(a[0:4])
jang_jae['시설주소']
# Out:
# 0               서울특별시 송파구 양산로10길 26
# 1      서울특별시 중랑구 망우로55길 32한국프라우드아파트
# 2                  충청북도 충주시 지속골길 71
# 3               서울특별시 강북구 오현로 199-9
# 4            서울특별시 용산구 한강대로 3311~2층
#                    ...
# 139
# 140              서울특별시 중랑구 상봉로 695층
# 141             서울특별시 은평구 갈현로11길 30
# 142           서울특별시 강동구 고덕로 106201호
# 143        서울특별시 은평구 갈현로11길 30(구산동)
# Name: 시설주소, Length: 144, dtype: object

# %%
#추출된 주소값을 csv파일로 보내고 , csv 파일 내에서 세부적인 주소 조정
jang_jae.to_csv('total2.csv' , encoding = 'euc-kr')
result2 = pd.read_csv('total2.csv' , encoding = 'euc-kr')
result2.head()
# Out:
#    Unnamed: 0           시설명                          시설주소
# 0           0    임마누엘보호작업시설           서울특별시 송파구 양산로10길 26
# 1           1          아름다운  서울특별시 중랑구 망우로55길 32한국프라우드아파트
# 2           2     마리스타보호작업장              충청북도 충주시 지속골길 71
# 3           3  강북구립장애인보호작업장           서울특별시 강북구 오현로 199-9
# 4           4  용산구립장애인보호작업장        서울특별시 용산구 한강대로 3311~2층

# %%
from geopy.geocoders import Nominatim
geo_local = Nominatim(user_agent='South Korea')
# 위도, 경도 반환하는 함수
def geocoding(address):
    try:
        geo = geo_local.geocode(address)
        x_y = [geo.latitude, geo.longitude]
        return x_y

    except:
        return [0,0]

# %%
#위의 함수를 통해서 주소를 기반으로 위도와 경도 추출
latitudee = []
longitudee =[]

for i in result2['시설주소']:
    latitudee.append(geocoding(i)[0])
    longitudee.append(geocoding(i)[1])

# %%
#위도와 경도를 원래 데이터프레임과 합치기
address_df2 = pd.DataFrame({'시설이름': result2['시설명'],'상세주소':result2['시설주소'],'위도':latitudee,'경도':longitudee})
result2 = address_df2[address_df2['위도'] != 0]
result2
# Out:
#                        시설이름                       상세주소         위도          경도
# 0                임마누엘보호작업시설        서울특별시 송파구 양산로10길 26  37.492239  127.145514
# 3              강북구립장애인보호작업장        서울특별시 강북구 오현로 199-9  37.629552  127.039482
# 4              용산구립장애인보호작업장     서울특별시 용산구 한강대로 3311~2층  37.521924  126.961617
# 5                  다니엘직업재활원    서울특별시 서초구 헌릉로468길 21-16  37.460304  127.089775
# 14                   삼성떡프린스      서울특별시 동작구 양녕로30길 19-4  37.499023  126.944980
# 21                  가브리엘작업장  서울특별시 노원구 한글비석로24라길 94-13  37.665327  127.070167
# 23              북부장애인직업재활시설       서울특별시 노원구 덕릉로70가길 92  37.643622  127.059375
# 28               바오로교실보호작업장          서울특별시 은평구 증산로5길 7  37.582628  126.907100
# 29                     열림일터         서울특별시 강서구 까치산로 136  37.554748  126.853652
# 30                     아람마을       서울특별시 노원구 월계로 338-16  37.626930  127.053855
# 38              실로암장애인근로사업장       서울특별시 관악구 남부순환로 1717  37.482923  126.941117
# 39                 성분도보호작업장        경기도 광주시 국사봉로 159-10  37.307538  127.357863
# 40          에스알씨(SRC)직업재활센터           경기도 성남시 중원구 둔촌대로  37.429494  127.124149
# 41                성모자애보호작업장       서울특별시 강남구 헌릉로757길 35  37.471247  127.119256
# 43                  성모보호작업장     서울특별시 성동구 금호산9가길 57-10  37.550885  127.017934
# 45               광진장애인보호작업장        서울특별시 광진구 동일로80길 20  37.570175  127.081250
# 49             구로구립장애인보호작업장           서울특별시 구로구 경인로 21  37.507461  126.888234
# 50                서울남부보호작업장      서울특별시 동작구 여의대방로20길 33  37.490444  126.917936
# 53              비둘기직업적응훈련센터          서울특별시 종로구 동숭4길 28  37.583743  127.005487
# 54        (사)대한안마사협회부설안마수련원     서울특별시 서초구 서초중앙로22길 105  37.493501  127.016622
# 57                  충현보호작업장        서울특별시 강남구 논현로98길 16  37.503787  127.037966
# 59               그라나다보호작업센터         서울특별시 강서구 허준로5길 37  37.568609  126.850703
# 60                기쁜우리보호작업장           서울특별시 강서구 허준로 65  37.570343  126.842971
# 64                     똘레랑스      서울특별시 은평구 연서로21길 31-0  37.614662  126.916634
# 68                  마라보호작업장      서울특별시 송파구 송이로34길 43-1  37.485120  127.129899
# 71                  은평보호작업장        서울특별시 은평구 갈현로11길 30  37.605176  126.907504
# 78                     희망일터         서울특별시 광진구 천호대로 622  37.553542  127.088319
# 83               드림장애인보호작업장            서울특별시 양천구 지양로 7  37.522551  126.825496
# 84                    행복한나무          서울특별시 영등포구 양산로 96  37.524566  126.893046
# 85              갑을장애인직업휴먼센터       서울특별시 관악구 난우16길 13-7  37.477524  126.919301
# 89          다사랑(대한정신보건가족협회)      서울특별시 강서구 개화동로7길 3-16  37.580015  126.799540
# 91                  강서나누리센터     서울특별시 강서구 공항대로7가길 21-3  37.562488  126.813734
# 96   중증장애인다수고용사업장굿윌스토어밀알도봉점       서울특별시 도봉구 마들로 664-17  37.662329  127.045879
# 100                빛나눔보호작업장       서울특별시 은평구 수색로 390-29  37.590047  126.885071
# 107                행복을파는장사꾼         서울특별시 강서구 까치산로 134  37.554748  126.853652
# 108             꿈드래장애인일자리센터      서울특별시 동대문구 장한로28가길 70  37.578820  127.074055
# 109             마포푸르메직업재활센터      서울특별시 마포구 월드컵북로 494-0  37.585298  126.878561
# 112                   SG블루웰         서울특별시 금천구 두산로 70-0  37.469555  126.898053
# 114                한우리보호작업장     서울특별시 서초구 남부순환로340길 15  37.480809  127.022680
# 115            늘품 장애인 보호작업장     서울특별시 서대문구 홍은중앙로 105-0  37.592577  126.944685
# 117            베데스다직업적응훈련시설       서울특별시 노원구 공릉로58마길 27  37.636897  127.078190
# 118          송파구장애인직업재활지원센터           서울특별시 송파구 양산로 5,  37.489774  127.142682
# 121                한결엠보호작업장     서울특별시 금천구 가산디지털1로 131,  37.473849  126.884489
# 122                    블루나래        서울특별시 구로구 디지털로 272,  37.485790  126.896310
# 123              두손장애인보호작업장      서울특별시 송파구 동남로6길 34-1,  37.487767  127.126806
# 125                    기쁨나무       서울특별시 금천구 시흥대로80길 19  37.459019  126.901003
# 128               두빛나래보호작업장          서울특별시 성동구 성수일로 10  37.546984  127.050933
# 129         강남세움근로사업장 굿윌스토어       서울특별시 강남구 광평로60길 22,  37.488256  127.106304
# 130             강남세움 직업훈련센터       서울특별시 강남구 광평로60길 22,  37.488256  127.106304
# 131             사랑손직업적응훈련시설          서울특별시 동작구 사당로 90,  37.484482  126.979546
# 132                  두리하나다울       서울특별시 구로구 경인로53길 90,  37.503780  126.875074
# 134                      소담          서울특별시 중랑구 상봉로 69,  37.595760  127.092992
# 135                   스프링샤인        서울특별시 은평구 갈현로11길 30  37.605176  126.907504
# 137                 다은보호작업장        서울특별시 은평구 통일로71길 8,  37.612604  126.926283
# 141                   스프링샤인        서울특별시 은평구 갈현로11길 30  37.605176  126.907504

# %%
#위의 seoul_map에다가 marker를 추가하는 작업
bokji_group = folium.FeatureGroup(name = '복지시설')
jae_group = folium.FeatureGroup(name = '재활시설')

for i in result.values:
    folium.CircleMarker([i[2], i[3]], popup=i[0] , radius=5, line_color='red',fill_color='red', fill_opacity=1).add_to(bokji_group)

for j in result2.values:
    folium.CircleMarker([j[2], j[3]], popup=j[0] , radius=5, line_color='blue',fill_color='blue', fill_opacity=1).add_to(jae_group)

bokji_group.add_to(seoul_map)
jae_group.add_to(seoul_map)

folium.LayerControl().add_to(seoul_map)
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec8f877b3e92e43dd9233f8fbcf78f43 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec8f877b3e92e43dd9233f8fbcf78f43&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ec8f877b3e92e43dd9233f8fbcf78f43 = L.map(
#                 &quot;map_ec8f877b3e92e43dd9233f8fbcf78f43&quot;,
#                 {
#                     center: [37.5665, 126.978],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d7deaf5578d2ad38a644f0ee83cdefe6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ec8f877b3e92e43dd9233f8fbcf78f43);
#
#
#             var choropleth_ce75a015f50af7c3df012701d0df44a0 = L.featureGroup(
#                 {}
#             ).addTo(map_ec8f877b3e92e43dd9233f8fbcf78f43);
#
#
#         function geo_json_d4f61139e64255f6269882e9735f2c4a_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;: case &quot;\uc911\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#66c2a4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ccece6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;: case &quot;\uc11c\ucd08\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#edf8fb&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2ca25f&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006d2c&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#99d8c9&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_d4f61139e64255f6269882e9735f2c4a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d4f61139e64255f6269882e9735f2c4a = L.geoJson(null, {
#                 onEachFeature: geo_json_d4f61139e64255f6269882e9735f2c4a_onEachFeature,
#
#                 style: geo_json_d4f61139e64255f6269882e9735f2c4a_styler,
#         });
#
#         function geo_json_d4f61139e64255f6269882e9735f2c4a_add (data) {
#             geo_json_d4f61139e64255f6269882e9735f2c4a
#                 .addData(data)
#                 .addTo(choropleth_ce75a015f50af7c3df012701d0df44a0);
#         }
#             geo_json_d4f61139e64255f6269882e9735f2c4a_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080893, 37.46240445587048], [1

# %% [markdown]
# import geopandas as gpd
# import matplotlib.pyplot as plt
#
#
# gdf = gpd.read_file('')
#
#
# fig, ax = plt.subplots(1, 1)
# gdf.plot(column='인구수', cmap='OrRd', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True)
#
#
# sm = plt.cm.ScalarMappable(cmap='OrRd', norm=plt.Normalize(vmin=gdf['인구수'].min(), vmax=gdf['인구수'].max()))
# sm._A = []
# cbar = fig.colorbar(sm)
#
#
# plt.title("인구수에 따른 지도 시각화")
# ax.set_axis_off()
#
# 결과 출력
# plt.show()

# %%
seoul_map.save('마커(복지시설).html')

# %%
seoul_map = folium.Map(location=[37.5665, 126.9780], zoom_start=10)
folium.Choropleth(
    geo_data=geo_str,
    data=total,
    columns=['GU_NAM', '장애인비율'],
    fill_color='BuGn',
    key_on='feature.properties.name',
).add_to(seoul_map)

for idx, row in total.iterrows():
    text = row['GU_NAM']
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        icon=folium.DivIcon(html=f'<div>{text}</div>') 
    ).add_to(seoul_map)

folium.TileLayer('stamenwatercolor').add_to(seoul_map)
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_235fef6de06caab00fc5327f1a1ebec5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_235fef6de06caab00fc5327f1a1ebec5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_235fef6de06caab00fc5327f1a1ebec5 = L.map(
#                 &quot;map_235fef6de06caab00fc5327f1a1ebec5&quot;,
#                 {
#                     center: [37.5665, 126.978],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fa9f1d29447e69fcf89373a326993a0e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_235fef6de06caab00fc5327f1a1ebec5);
#
#
#             var choropleth_64c3462b8261e75b3db915909c884bc7 = L.featureGroup(
#                 {}
#             ).addTo(map_235fef6de06caab00fc5327f1a1ebec5);
#
#
#         function geo_json_4b34c33cc068ee475439cca5973f6ecb_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;: case &quot;\uc911\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#66c2a4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ccece6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;: case &quot;\uc11c\ucd08\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#edf8fb&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2ca25f&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006d2c&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#99d8c9&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_4b34c33cc068ee475439cca5973f6ecb_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_4b34c33cc068ee475439cca5973f6ecb = L.geoJson(null, {
#                 onEachFeature: geo_json_4b34c33cc068ee475439cca5973f6ecb_onEachFeature,
#
#                 style: geo_json_4b34c33cc068ee475439cca5973f6ecb_styler,
#         });
#
#         function geo_json_4b34c33cc068ee475439cca5973f6ecb_add (data) {
#             geo_json_4b34c33cc068ee475439cca5973f6ecb
#                 .addData(data)
#                 .addTo(choropleth_64c3462b8261e75b3db915909c884bc7);
#         }
#             geo_json_4b34c33cc068ee475439cca5973f6ecb_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080893, 37.46240445587048], [1

# %%
#불러온 파일에서 필요한 부분만 추출
jang_ji = jang_ji[['시설명','시설주소']]
jang_ji.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시설명     238 non-null    object
#  1   시설주소    238 non-null    object
# dtypes: object(2)
# memory usage: 3.8+ KB

# %%
#주소값들을 'n층'과 같이 꼬리에 붙어있는 것들을 제거하고 순수 주소값으로 추출
for i in range(len(jang_ji)):
    a = jang_ji['시설주소'][i].split(' ')
    jang_ji['시설주소'][i] = " ".join(a[0:4])
jang_ji['시설주소']
# Out:
# 0                       서울특별시 송파구 백제고분로37길 4
# 1                      서울특별시 송파구 삼학사로19길 27
# 2         서울특별시 동작구 여의대방로20길 33-0395(보라매공원내)
# 3                       서울특별시 강남구 봉은사로50길 6
# 4      서울특별시 마포구 성산로4길 353층(마포장애인종합복지관)(성산동)
#                        ...
# 233               서울특별시 노원구 상계로23다길 13-8107호
# 234                         서울특별시 성동구 무학로 50
# 235                      서울특별시 마포구 숭문길 14마포구
# 236                  서울특별시 마포구 백범로31길 21행복주택
# 237             서울특별시 광진구 동일로 357아이맘인지행동발달센터
# Name: 시설주소, Length: 238, dtype: object

# %%
jang_ji.to_csv('total3.csv' , encoding = 'euc-kr')

# %%
result4 = pd.read_csv('total3.csv' , encoding = 'euc-kr')

# %%
result4
# Out:
#      Unnamed: 0                  시설명                                   시설주소
# 0             0             송파구방이복지관                   서울특별시 송파구 백제고분로37길 4
# 1             1           서울시각장애인복지관                  서울특별시 송파구 삼학사로19길 27
# 2             2         서울시립발달장애인복지관     서울특별시 동작구 여의대방로20길 33-0395(보라매공원내)
# 3             3                청음복지관                   서울특별시 강남구 봉은사로50길 6
# 4             4           마포장애인종합복지관  서울특별시 마포구 성산로4길 353층(마포장애인종합복지관)(성산동)
# ..          ...                  ...                                    ...
# 233         233          킨더윌언어심리전문센터             서울특별시 노원구 상계로23다길 13-8107호
# 234         234              시설테스트1호                       서울특별시 성동구 무학로 50
# 235         235   염리종합사회복지관 내 주간보호센터                    서울특별시 마포구 숭문길 14마포구
# 236         236  공덕동행복주택 내 장애인주간보호센터                서울특별시 마포구 백범로31길 21행복주택
# 237         237          아이맘인지행동발달센터           서울특별시 광진구 동일로 357아이맘인지행동발달센터
#
# [238 rows x 3 columns]

# %%
#위의 함수를 통해서 주소를 기반으로 위도와 경도 추출
latitudee = []
longitudee =[]

for i in result4['시설주소']:
    latitudee.append(geocoding(i)[0])
    longitudee.append(geocoding(i)[1])

# %%
#위도와 경도를 원래 데이터프레임과 합치기
address_df3 = pd.DataFrame({'시설이름': result4['시설명'],'상세주소':result4['시설주소'],'위도':latitudee,'경도':longitudee})
result5 = address_df3[address_df3['위도'] != 0]
result5
# Out:
#                     시설이름                        상세주소         위도          경도
# 0               송파구방이복지관        서울특별시 송파구 백제고분로37길 4  37.504183  127.104948
# 1             서울시각장애인복지관       서울특별시 송파구 삼학사로19길 27　  37.506181  127.094025
# 3                  청음복지관        서울특별시 강남구 봉은사로50길 6　  37.509070  127.042752
# 7         성프란치스꼬장애인종합복지관  서울특별시 구로구 남부순환로105라길 25-10  37.480449  126.889352
# 8                성모자애복지관       서울특별시 강남구 헌릉로757길 35　  37.471247  127.119256
# ..                   ...                         ...        ...         ...
# 227             양천희망돌봄센터         서울특별시 양천구 가로공원로 101  37.537030  126.833599
# 228         은평구립우리장애인복지관          서울특별시 은평구 녹번로1길 13  37.605269  126.926300
# 229        금천발달장애인주간보호센터       서울특별시 금천구 시흥대로73길 30,  37.457137  126.899291
# 230  40플러스 금곡행복쉼터 주간보호센터       서울특별시 강서구 방화대로45길 69,  37.574292  126.813974
# 234              시설테스트1호            서울특별시 성동구 무학로 50  37.566591  127.030094
#
# [99 rows x 4 columns]

# %%
#위의 seoul_map에다가 marker를 추가하는 작업
bokji_group = folium.FeatureGroup(name = '복지시설')
jae_group = folium.FeatureGroup(name = '직업재활시설')
ji_group = folium.FeatureGroup(name = '사회재활시설')

for i in result.values:
    folium.CircleMarker([i[2], i[3]], popup=i[0] , radius=5, line_color='red',fill_color='red', fill_opacity=1).add_to(bokji_group)

for j in result2.values:
    folium.CircleMarker([j[2], j[3]], popup=j[0] , radius=5, line_color='blue',fill_color='blue', fill_opacity=1).add_to(jae_group)

for k in result5.values:
    folium.CircleMarker([k[2], k[3]], popup=k[0] , radius=5, line_color='green',fill_color='green', fill_opacity=1).add_to(ji_group)

bokji_group.add_to(seoul_map)
jae_group.add_to(seoul_map)
ji_group.add_to(seoul_map)

folium.LayerControl().add_to(seoul_map)
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_235fef6de06caab00fc5327f1a1ebec5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_235fef6de06caab00fc5327f1a1ebec5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_235fef6de06caab00fc5327f1a1ebec5 = L.map(
#                 &quot;map_235fef6de06caab00fc5327f1a1ebec5&quot;,
#                 {
#                     center: [37.5665, 126.978],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fa9f1d29447e69fcf89373a326993a0e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_235fef6de06caab00fc5327f1a1ebec5);
#
#
#             var choropleth_64c3462b8261e75b3db915909c884bc7 = L.featureGroup(
#                 {}
#             ).addTo(map_235fef6de06caab00fc5327f1a1ebec5);
#
#
#         function geo_json_4b34c33cc068ee475439cca5973f6ecb_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;: case &quot;\uc911\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#66c2a4&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ccece6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;: case &quot;\uc11c\ucd08\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#edf8fb&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#2ca25f&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\uac15\ubd81\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006d2c&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#99d8c9&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_4b34c33cc068ee475439cca5973f6ecb_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_4b34c33cc068ee475439cca5973f6ecb = L.geoJson(null, {
#                 onEachFeature: geo_json_4b34c33cc068ee475439cca5973f6ecb_onEachFeature,
#
#                 style: geo_json_4b34c33cc068ee475439cca5973f6ecb_styler,
#         });
#
#         function geo_json_4b34c33cc068ee475439cca5973f6ecb_add (data) {
#             geo_json_4b34c33cc068ee475439cca5973f6ecb
#                 .addData(data)
#                 .addTo(choropleth_64c3462b8261e75b3db915909c884bc7);
#         }
#             geo_json_4b34c33cc068ee475439cca5973f6ecb_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080893, 37.46240445587048], [1
